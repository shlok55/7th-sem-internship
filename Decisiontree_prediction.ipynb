# %%
import pandas as pd
from river import datasets
from river import evaluate
from river import metrics
from river import stream
from river.tree import HoeffdingTreeClassifier

# %%
# Load the CSV file using pandas
data = pd.read_csv('Customer_Behaviour.csv')

# %%
# Convert the DataFrame into a River-compatible stream
stream_data = stream.iter_pandas(X=data.drop('Purchased', axis=1), y=data['Purchased'])

# %%
# Define the model
model = HoeffdingTreeClassifier()

# %%
# Define the metric for evaluation
metric = metrics.Accuracy()

# %%
# Perform the evaluation
evaluate.progressive_val_score(stream_data, model, metric)

# Print the accuracy
print(f'Accuracy: {metric.get()}')
# Out:
# Accuracy: 0.8446115288220551

# %%
import matplotlib.pyplot as plt

# Accuracy value
accuracy = 84.46

# Create a list with accuracy and remaining percentage
accuracies = [accuracy, 100 - accuracy]

# Labels for each category
labels = ['Accuracy', 'Remaining']

# Colors for each category
colors = ['green', 'gray']

# Create the pie chart
plt.pie(accuracies, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)

# Add a title
plt.title('Accuracy')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Display the pie chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Accuracy value
accuracy = 84.46

# Calculate remaining percentage
remaining = 100 - accuracy

# Create x-axis values
x = [0, 1]

# Create y-axis values
y1 = [accuracy, accuracy]
y2 = [0, remaining]

# Create the area chart
plt.fill_between(x, y1, alpha=0.5, color='green', label='Accuracy')
plt.fill_between(x, y2, alpha=0.5, color='gray', label='Remaining')

# Set x-axis labels
plt.xticks(x, ['Accuracy', ''])

# Set y-axis label
plt.ylabel('Percentage')

# Add a title
plt.title('Accuracy')

# Display the legend
plt.legend()

# Display the area chart
plt.show()
